# %%
import pandas as pd
df=pd.read_csv('apt202112.csv',encoding='cp949')
df2=pd.read_csv('apt_comma.csv',encoding='cp949')

# %%
df
# Out:
#                 시군구      번지    본번  부번           단지명  전용면적(㎡)    계약년월  계약일  \
# 0       강원도 강릉시 견소동     202  0202   0          송정한신  84.9300  202112    7
# 1       강원도 강릉시 견소동     202  0202   0          송정한신  39.0800  202112   11
# 2       강원도 강릉시 견소동     202  0202   0          송정한신  59.8000  202112   13
# 3       강원도 강릉시 견소동     202  0202   0          송정한신  39.0800  202112   14
# 4       강원도 강릉시 견소동     289  0289   0  송정해변신도브래뉴아파트  59.9900  202112    1
# ...             ...     ...   ...  ..           ...      ...     ...  ...
# 20570  충청북도 충주시 호암동  558-16  0558  16            한양  59.8400  202112    7
# 20571  충청북도 충주시 호암동     905  0905   0         호암동수채  84.9289  202112    8
# 20572  충청북도 충주시 호암동  221-23  0221  23    호암리버빌(1단지)  84.6800  202112    3
# 20573  충청북도 충주시 호암동  221-23  0221  23    호암리버빌(1단지)  84.6800  202112    6
# 20574  충청북도 충주시 호암동  221-23  0221  23    호암리버빌(1단지)  84.6800  202112   19
#
#              거래금액(만원)   층    건축년도           도로명  해제사유발생일  거래유형  중개사소재지
# ...

# %%
df.거래금액=df.거래금액.str.replace(',','').astype('int64')

# %%
df2.가격=df2.가격.str.replace(',','').astype('int64')

# %%
df[df.시군구.str.find('안양동안구')>-1]
# Out:
#                 시군구       번지    본번  부번              단지명      전용면적    계약년월  \
# 2898  경기도 안양동안구 관양동     1669  1669   0        동편마을(4단지)  120.4800  202112
# 2899  경기도 안양동안구 관양동   1461-9  1461   9              신태양   50.8600  202112
# 2900  경기도 안양동안구 관양동  1461-10  1461  10             신태양B   52.3700  202112
# 2901  경기도 안양동안구 관양동     1815  1815   0        평촌더샵센트럴시티   59.9970  202112
# 2902  경기도 안양동안구 관양동     1815  1815   0        평촌더샵센트럴시티   59.9970  202112
# 2903  경기도 안양동안구 관양동   1589-1  1589   1          한가람(신라)   59.7600  202112
# 2904  경기도 안양동안구 관양동   1589-1  1589   1          한가람(신라)   42.7300  202112
# 2905  경기도 안양동안구 비산동    566-5  0566   5               강남   65.7900  202112
# 2906  경기도 안양동안구 비산동     1155  1155   0            그린빌주공   49.4800  202112
# 2907  경기도 안양동안구 비산동   1109-4  1109   4  샛별한양6(고층1109-4)   35.1000  202112
# 2908  경기도 안양동안구 비산동   1109-4  1109   4  샛별한양6(고층1109-4)   42.6150  202112
# 2909  경기도 안양동안구 비산동   1109-6  1109   6  샛별한양6(고층1109-6)   28.2150  202112
# ...

# %%
df[(df.거래금액>100000) & (df.시군구.str.find('안양동안구')>-1)].loc[:,["단지명","전용면적","거래금액"]]
# Out:
#             단지명     전용면적    거래금액
# 2898  동편마을(4단지)  120.480  152000
# 2901  평촌더샵센트럴시티   59.997  105000
# 2902  평촌더샵센트럴시티   59.997  101500
# 2911      꿈마을동아  130.080  120000
# 2912     꿈마을라이프  110.357  130000
